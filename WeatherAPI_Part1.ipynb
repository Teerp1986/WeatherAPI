# %%
baseurl = "http://api.weatherapi.com/v1"
ailene_key = "97b09a7edb86430e9fb191726253112"
#key = "<YOUR_API_KEY>"

# %%
#http://api.weatherapi.com/v1/current.json?key=<YOUR_API_KEY>&q=London

# %%
import requests
import pandas as pd

# %%
city = "Louisville"
baseurl = f"http://api.weatherapi.com/v1/current.json?key={ailene_key}&q={city}"
response = requests.get(baseurl)

# %%
response.status_code
# Out:
# 200

# %%
data =response.json()
data
# Out:
# {'location': {'name': 'Louisville',
#   'region': 'Kentucky',
#   'country': 'United States of America',
#   'lat': 38.2542,
#   'lon': -85.7594,
#   'tz_id': 'America/Kentucky/Louisville',
#   'localtime_epoch': 1767210875,
#   'localtime': '2025-12-31 14:54'},
#  'current': {'last_updated_epoch': 1767210300,
#   'last_updated': '2025-12-31 14:45',
#   'temp_c': 3.9,
#   'temp_f': 39.0,
#   'is_day': 1,
#   'condition': {'text': 'Overcast',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#    'code': 1009},
#   'wind_mph': 9.2,
#   'wind_kph': 14.8,
#   'wind_degree': 258,
#   'wind_dir': 'WSW',
#   'pressure_mb': 1015.0,
#   'pressure_in': 29.96,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 57,
#   'cloud': 100,
#   'feelslike_c': 0.4,
#   'feelslike_f': 32.8,
#   'windchill_c': -1.0,
#   'windchill_f': 30.2,
#   'heatindex_c': 2.6,
#   'heatindex_f': 36.7,
#   'dewpoint_c': -0.2,
#   'dewpoint_f': 31.6,
#   'vis_km': 16.0,
#   'vis_miles': 9.0,
# ...

# %%
current = data['current']
location = data['location']
temp_f =current['temp_f']
wind_mph = current['wind_mph']
humidity = current['humidity']

# %%
temp_f, humidity
# Out:
# (39.0, 57)

# %%
def get_weather(city):
    url = f"http://api.weatherapi.com/v1/current.json?key={ailene_key}&q={city}"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        current = data['current']
        location = data['location']
        temp_f = current['temp_f']
        humidity = current['humidity']
        

        print(f"Weather for {location['name']}, {location['region']}")
        print(f"Temperature: {current ['temp_f']} °F / {current['temp_c']} °C")
        print(f"Condition: {current ['condition']['text']}")
        print(f"Humidity: {current ['humidity']}%")
        print(f"Wind Speed: {current ['wind_mph']} mph")


    else:
        print(f"Error fetching data for {city}: {response.status_code}")

# %%
get_weather("Louisville")
# Out:
# Weather for Louisville, Kentucky
# Temperature: 39.0 °F / 3.9 °C
# Condition: Overcast
# Humidity: 59%
# Wind Speed: 8.9 mph

# %%
get_weather("New York")
# Out:
# Weather for New York, New York
# Temperature: 30.9 °F / -0.6 °C
# Condition: Overcast
# Humidity: 47%
# Wind Speed: 13.4 mph

# %%
get_weather("Hnolulu")
# Out:
# Error fetching data for Hnolulu: 400

# %%
get_weather("Honolulu")
# Out:
# Weather for Honolulu, Hawaii
# Temperature: 75.2 °F / 24.0 °C
# Condition: Light rain
# Humidity: 74%
# Wind Speed: 18.3 mph

# %%
cities = ["Louisville", "New York", "Honolulu", "Chicago", "Miami"]
weather_data = []
for city in cities:
    url = f"http://api.weatherapi.com/v1/current.json?key={ailene_key}&q={city}"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        #current = data['current']
        #location = data['location']
        weather_data.append({
            "City": data['location']['name'],
            "Temperature (F)": data['current']['temp_f'],
            "Condition": data['current']['condition'],
            "Humidity": data['current']['humidity'],
            "Wind Speed": data['current']['wind_mph']})
    else:
        print(f"Error fetching data")

# %%
weather_data
# Out:
# [{'City': 'Louisville',
#   'Temperature (F)': 39.0,
#   'Condition': {'text': 'Overcast',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#    'code': 1009},
#   'Humidity': 59,
#   'Wind Speed': 8.9},
#  {'City': 'New York',
#   'Temperature (F)': 30.9,
#   'Condition': {'text': 'Overcast',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#    'code': 1009},
#   'Humidity': 47,
#   'Wind Speed': 13.4},
#  {'City': 'Honolulu',
#   'Temperature (F)': 75.2,
#   'Condition': {'text': 'Light rain',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/296.png',
#    'code': 1183},
#   'Humidity': 74,
#   'Wind Speed': 18.3},
#  {'City': 'Chicago',
#   'Temperature (F)': 35.1,
#   'Condition': {'text': 'Overcast',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#    'code': 1009},
#   'Humidity': 82,
#   'Wind Speed': 13.6},
#  {'City': 'Miami',
#   'Temperature (F)': 63.0,
#   'Condition': {'text': 'Sunny',
# ...

# %%
weather_df = pd.DataFrame(weather_data)
weather_df.head()
# Out:
#          City  Temperature (F)  \
# 0  Louisville             39.0
# 1    New York             30.9
# 2    Honolulu             75.2
# 3     Chicago             35.1
# 4       Miami             63.0
#
#                                            Condition  Humidity  Wind Speed
# 0  {'text': 'Overcast', 'icon': '//cdn.weatherapi...        59         8.9
# 1  {'text': 'Overcast', 'icon': '//cdn.weatherapi...        47        13.4
# 2  {'text': 'Light rain', 'icon': '//cdn.weathera...        74        18.3
# 3  {'text': 'Overcast', 'icon': '//cdn.weatherapi...        82        13.6
# 4  {'text': 'Sunny', 'icon': '//cdn.weatherapi.co...        34        10.7

# %%
weather_df.to_csv("sample_weather_data.csv", index=False)
